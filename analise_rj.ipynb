# %% [markdown]
# <a href="https://colab.research.google.com/github/ranielli/analise-dados-covid-estatistica/blob/main/trabalho_IA_estatisca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análise de Covid 19  - Município do Rio de Janeiro X Estado do RJ**
# Autor: Rânielli Neves

# %% [markdown]
# * Preparação do Ambiente e criação dos **datasets**

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
# %matplotlib inline


data_20p1= pd.read_csv('dados/HIST_PAINEL_COVIDBR_2020_Parte1_14jul2021_new.csv', sep=';',low_memory=False)
data_20p2= pd.read_csv('dados/HIST_PAINEL_COVIDBR_2020_Parte2_14jul2021.csv', sep=';',low_memory=False)
data_21p1= pd.read_csv('dados/HIST_PAINEL_COVIDBR_2021_Parte1_14jul2021.csv', sep=';',low_memory=False)
data_21p2= pd.read_csv('dados/HIST_PAINEL_COVIDBR_2021_Parte2_14jul2021.csv', sep=';',low_memory=False)

# %% [markdown]
# * Unificação dos datasets

# %%
data_geral = pd.concat([data_20p1, data_20p2, data_21p1,data_21p2])

# %%
data_geral.head()
# Out:
#        regiao estado municipio  coduf  codmun codRegiaoSaude nomeRegiaoSaude  \
# Brasil    NaN    NaN        76    NaN     NaN            NaN      2020-02-25
# Brasil    NaN    NaN        76    NaN     NaN            NaN      2020-02-26
# Brasil    NaN    NaN        76    NaN     NaN            NaN      2020-02-27
# Brasil    NaN    NaN        76    NaN     NaN            NaN      2020-02-28
# Brasil    NaN    NaN        76    NaN     NaN            NaN      2020-02-29
#
#        data    semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# Brasil    9  210147125.0               0.0             0.0           0
# Brasil    9  210147125.0               1.0             1.0           0
# Brasil    9  210147125.0               1.0             0.0           0
# Brasil    9  210147125.0               1.0             0.0           0
# Brasil    9  210147125.0               2.0             1.0           0
#
#         obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# Brasil                0          NaN               NaN                    NaN
# Brasil                0          NaN               NaN                    NaN
# Brasil                0          NaN               NaN                    NaN
# Brasil                0          NaN               NaN                    NaN
# Brasil                0          NaN               NaN                    NaN
#
#         interior/metropolitana
# Brasil                     NaN
# Brasil                     NaN
# Brasil                     NaN
# Brasil                     NaN
# Brasil                     NaN

# %% [markdown]
# ##Análise do Município Rio de Janeiro
# * Criando um dataframe Município Rio de Janeiro

# %%
geral_munic_rj = data_geral[data_geral.municipio =='Rio de Janeiro']
geral_munic_rj
# Out:
#          regiao estado       municipio  coduf    codmun codRegiaoSaude  \
# 502606  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 502607  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 502608  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 502609  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 502610  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# ...         ...    ...             ...    ...       ...            ...
# 45999   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 46000   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 46001   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 46002   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 46003   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
#
#         nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 502606  METROPOLITANA I  2020-08-01       31.0         6718903.0
# 502607  METROPOLITANA I  2020-08-02       32.0         6718903.0
# 502608  METROPOLITANA I  2020-08-03       32.0         6718903.0
# 502609  METROPOLITANA I  2020-08-04       32.0         6718903.0
# 502610  METROPOLITANA I  2020-08-05       32.0         6718903.0
# ...                 ...         ...        ...               ...
# 45999   METROPOLITANA I  2021-07-10       27.0         6718903.0
# 46000   METROPOLITANA I  2021-07-11       28.0         6718903.0
# 46001   METROPOLITANA I  2021-07-12       28.0         6718903.0
# 46002   METROPOLITANA I  2021-07-13       28.0         6718903.0
# 46003   METROPOLITANA I  2021-07-14       28.0         6718903.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 502606         71792.0         470             8344         34.0
# 502607         71802.0          10             8358         14.0
# 502608         72079.0         277             8371         13.0
# 502609         72722.0         643             8419         48.0
# 502610         73396.0         674             8499         80.0
# ...                ...         ...              ...          ...
# 45999         375242.0        1466            29175        133.0
# 46000         375616.0         374            29185         10.0
# 46001         375908.0         292            29192          7.0
# 46002         376763.0         855            29241         49.0
# 46003         378301.0        1538            29295         54.0
#
#         Recuperadosnovos  emAcompanhamentoNovos  interior/metropolitana
# 502606               NaN                    NaN                     1.0
# 502607               NaN                    NaN                     1.0
# 502608               NaN                    NaN                     1.0
# 502609               NaN                    NaN                     1.0
# 502610               NaN                    NaN                     1.0
# ...                  ...                    ...                     ...
# 45999                NaN                    NaN                     1.0
# 46000                NaN                    NaN                     1.0
# 46001                NaN                    NaN                     1.0
# 46002                NaN                    NaN                     1.0
# 46003                NaN                    NaN                     1.0
#
# [348 rows x 17 columns]

# %% [markdown]
# * Covertendo a coluna data para formato datetime

# %%
geral_munic_rj['data'] = pd.to_datetime(geral_munic_rj['data'])

# %% [markdown]
# * Estrutura do dataframe

# %%
geral_munic_rj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 348 entries, 502606 to 46003
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   regiao                  348 non-null    object
#  1   estado                  348 non-null    object
#  2   municipio               348 non-null    object
#  3   coduf                   348 non-null    float64
#  4   codmun                  348 non-null    float64
#  5   codRegiaoSaude          348 non-null    object
#  6   nomeRegiaoSaude         348 non-null    object
#  7   data                    348 non-null    datetime64[ns]
#  8   semanaEpi               348 non-null    float64
#  9   populacaoTCU2019        348 non-null    float64
#  10  casosAcumulado          348 non-null    float64
#  11  casosNovos              348 non-null    int64
#  12  obitosAcumulado         348 non-null    int64
#  13  obitosNovos             348 non-null    float64
#  14  Recuperadosnovos        0 non-null      float64
#  15  emAcompanhamentoNovos   0 non-null      float64
#  16  interior/metropolitana  348 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(5)
# memory usage: 48.9+ KB

# %%
geral_munic_rj
# Out:
#          regiao estado       municipio  coduf    codmun codRegiaoSaude  \
# 502606  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 502607  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 502608  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 502609  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 502610  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# ...         ...    ...             ...    ...       ...            ...
# 45999   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 46000   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 46001   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 46002   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 46003   Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
#
#         nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  \
# 502606  METROPOLITANA I 2020-08-01       31.0         6718903.0
# 502607  METROPOLITANA I 2020-08-02       32.0         6718903.0
# 502608  METROPOLITANA I 2020-08-03       32.0         6718903.0
# 502609  METROPOLITANA I 2020-08-04       32.0         6718903.0
# 502610  METROPOLITANA I 2020-08-05       32.0         6718903.0
# ...                 ...        ...        ...               ...
# 45999   METROPOLITANA I 2021-07-10       27.0         6718903.0
# 46000   METROPOLITANA I 2021-07-11       28.0         6718903.0
# 46001   METROPOLITANA I 2021-07-12       28.0         6718903.0
# 46002   METROPOLITANA I 2021-07-13       28.0         6718903.0
# 46003   METROPOLITANA I 2021-07-14       28.0         6718903.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 502606         71792.0         470             8344         34.0
# 502607         71802.0          10             8358         14.0
# 502608         72079.0         277             8371         13.0
# 502609         72722.0         643             8419         48.0
# 502610         73396.0         674             8499         80.0
# ...                ...         ...              ...          ...
# 45999         375242.0        1466            29175        133.0
# 46000         375616.0         374            29185         10.0
# 46001         375908.0         292            29192          7.0
# 46002         376763.0         855            29241         49.0
# 46003         378301.0        1538            29295         54.0
#
#         Recuperadosnovos  emAcompanhamentoNovos  interior/metropolitana
# 502606               NaN                    NaN                     1.0
# 502607               NaN                    NaN                     1.0
# 502608               NaN                    NaN                     1.0
# 502609               NaN                    NaN                     1.0
# 502610               NaN                    NaN                     1.0
# ...                  ...                    ...                     ...
# 45999                NaN                    NaN                     1.0
# 46000                NaN                    NaN                     1.0
# 46001                NaN                    NaN                     1.0
# 46002                NaN                    NaN                     1.0
# 46003                NaN                    NaN                     1.0
#
# [348 rows x 17 columns]

# %% [markdown]
# ### Métricas do município do Rio de Janeiro  **Junho 2021**

# %%
mun_rj_junho_2021 = geral_munic_rj[(geral_munic_rj['data'] >= '2021-06-01' ) & (geral_munic_rj['data'] <= '2021-06-30' )]
mun_rj_junho_2021
# Out:
#          regiao estado       municipio  coduf    codmun codRegiaoSaude  \
# 594737  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594738  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594739  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594740  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594741  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594742  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594743  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594744  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594745  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594746  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594747  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594748  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594749  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594750  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594751  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594752  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594753  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594754  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594755  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594756  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594757  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594758  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594759  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594760  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594761  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594762  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594763  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594764  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594765  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 594766  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
#
#         nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  \
# 594737  METROPOLITANA I 2021-06-01       22.0         6718903.0
# 594738  METROPOLITANA I 2021-06-02       22.0         6718903.0
# 594739  METROPOLITANA I 2021-06-03       22.0         6718903.0
# 594740  METROPOLITANA I 2021-06-04       22.0         6718903.0
# 594741  METROPOLITANA I 2021-06-05       22.0         6718903.0
# 594742  METROPOLITANA I 2021-06-06       23.0         6718903.0
# 594743  METROPOLITANA I 2021-06-07       23.0         6718903.0
# 594744  METROPOLITANA I 2021-06-08       23.0         6718903.0
# 594745  METROPOLITANA I 2021-06-09       23.0         6718903.0
# 594746  METROPOLITANA I 2021-06-10       23.0         6718903.0
# 594747  METROPOLITANA I 2021-06-11       23.0         6718903.0
# 594748  METROPOLITANA I 2021-06-12       23.0         6718903.0
# 594749  METROPOLITANA I 2021-06-13       24.0         6718903.0
# 594750  METROPOLITANA I 2021-06-14       24.0         6718903.0
# 594751  METROPOLITANA I 2021-06-15       24.0         6718903.0
# 594752  METROPOLITANA I 2021-06-16       24.0         6718903.0
# 594753  METROPOLITANA I 2021-06-17       24.0         6718903.0
# 594754  METROPOLITANA I 2021-06-18       24.0         6718903.0
# 594755  METROPOLITANA I 2021-06-19       24.0         6718903.0
# 594756  METROPOLITANA I 2021-06-20       25.0         6718903.0
# 594757  METROPOLITANA I 2021-06-21       25.0         6718903.0
# 594758  METROPOLITANA I 2021-06-22       25.0         6718903.0
# 594759  METROPOLITANA I 2021-06-23       25.0         6718903.0
# 594760  METROPOLITANA I 2021-06-24       25.0         6718903.0
# 594761  METROPOLITANA I 2021-06-25       25.0         6718903.0
# 594762  METROPOLITANA I 2021-06-26       25.0         6718903.0
# 594763  METROPOLITANA I 2021-06-27       26.0         6718903.0
# 594764  METROPOLITANA I 2021-06-28       26.0         6718903.0
# 594765  METROPOLITANA I 2021-06-29       26.0         6718903.0
# 594766  METROPOLITANA I 2021-06-30       26.0         6718903.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 594737        326549.0        2004            26437        137.0
# 594738        329059.0        2510            26555        118.0
# 594739        330941.0        1882            26667        112.0
# 594740        331689.0         748            26689         22.0
# 594741        333467.0        1778            26765         76.0
# 594742        333949.0         482            26765          0.0
# 594743        334158.0         209            26765          0.0
# 594744        336235.0        2077            26933        168.0
# 594745        338716.0        2481            27036        103.0
# 594746        340672.0        1956            27173        137.0
# 594747        342568.0        1896            27297        124.0
# 594748        344623.0        2055            27397        100.0
# 594749        345044.0         421            27417         20.0
# 594750        345256.0         212            27428         11.0
# 594751        347120.0        1864            27548        120.0
# 594752        349605.0        2485            27657        109.0
# 594753        352190.0        2585            27781        124.0
# 594754        354143.0        1953            27832         51.0
# 594755        355773.0        1630            27930         98.0
# 594756        356028.0         255            27989         59.0
# 594757        356196.0         168            27997          8.0
# 594758        358329.0        2133            28103        106.0
# 594759        360465.0        2136            28209        106.0
# 594760        362131.0        1666            28270         61.0
# 594761        363968.0        1837            28337         67.0
# 594762        365506.0        1538            28405         68.0
# 594763        365892.0         386            28408          3.0
# 594764        365927.0          35            28418         10.0
# 594765        367347.0        1420            28506         88.0
# 594766        367579.0         232            28616        110.0
#
#         Recuperadosnovos  emAcompanhamentoNovos  interior/metropolitana
# 594737               NaN                    NaN                     1.0
# 594738               NaN                    NaN                     1.0
# 594739               NaN                    NaN                     1.0
# 594740               NaN                    NaN                     1.0
# 594741               NaN                    NaN                     1.0
# 594742               NaN                    NaN                     1.0
# 594743               NaN                    NaN                     1.0
# 594744               NaN                    NaN                     1.0
# 594745               NaN                    NaN                     1.0
# 594746               NaN                    NaN                     1.0
# 594747               NaN                    NaN                     1.0
# 594748               NaN                    NaN                     1.0
# 594749               NaN                    NaN                     1.0
# 594750               NaN                    NaN                     1.0
# 594751               NaN                    NaN                     1.0
# 594752               NaN                    NaN                     1.0
# 594753               NaN                    NaN                     1.0
# 594754               NaN                    NaN                     1.0
# 594755               NaN                    NaN                     1.0
# 594756               NaN                    NaN                     1.0
# 594757               NaN                    NaN                     1.0
# 594758               NaN                    NaN                     1.0
# 594759               NaN                    NaN                     1.0
# 594760               NaN                    NaN                     1.0
# 594761               NaN                    NaN                     1.0
# 594762               NaN                    NaN                     1.0
# 594763               NaN                    NaN                     1.0
# 594764               NaN                    NaN                     1.0
# 594765               NaN                    NaN                     1.0
# 594766               NaN                    NaN                     1.0

# %% [markdown]
# * <font color="ffd11b">**Média de Casos no Mês de Junho 2021**

# %%
mun_rj_junho_2021_media_casos =  mun_rj_junho_2021['casosNovos'].mean()
mun_rj_junho_2021_media_casos
# Out:
# 1434.4666666666667

# %% [markdown]
# * <font color="ffd11b"> **Desvio padrão de Casos no Mês de Junho 2021**

# %%
mun_rj_junho_2021_desvio_casos =  mun_rj_junho_2021['casosNovos'].std()
mun_rj_junho_2021_desvio_casos
# Out:
# 855.0811509515595

# %% [markdown]
# * <font color="ffd11b"> **Móda de Casos no Mês de Junho 2021**

# %%
mun_rj_junho_2021_moda_casos =  mun_rj_junho_2021['casosNovos'].mode()
mun_rj_junho_2021_moda_casos
# Out:
# 0       35
# 1      168
# 2      209
# 3      212
# 4      232
# 5      255
# 6      386
# 7      421
# 8      482
# 9      748
# 10    1420
# 11    1538
# 12    1630
# 13    1666
# 14    1778
# 15    1837
# 16    1864
# 17    1882
# 18    1896
# 19    1953
# 20    1956
# 21    2004
# 22    2055
# 23    2077
# 24    2133
# 25    2136
# 26    2481
# 27    2485
# 28    2510
# 29    2585
# dtype: int64

# %% [markdown]
#  * <font color="ffd11b"> **Análise de Casos Novos do Município do RJ no Mês de Junho 2021**

# %%
quartis_mun_rj_junho_casos = mun_rj_junho_2021['casosNovos'].quantile([0.25,0.5,0.75])
quartis_mun_rj_junho_casos
# Out:
# 0.25     436.25
# 0.50    1807.50
# 0.75    2042.25
# Name: casosNovos, dtype: float64

# %%
boxplot_mun_rj_junho_casos = mun_rj_junho_2021.boxplot(column=['casosNovos'], showfliers=False)
boxplot_mun_rj_junho_casos.plot()
plt.title("Distribuição de novos casos Município do RJ - Junho 2021")
plt.show()

# %% [markdown]
# *  <font color="red">**Média de Óbitos no Mês de Junho 2021** </font>

# %%
mun_rj_junho_2021_media_obitos =  mun_rj_junho_2021['obitosNovos'].mean()
mun_rj_junho_2021_media_obitos
# Out:
# 77.2

# %% [markdown]
# * <font color="red"> **Desvio Padrão de Óbitos no Mês de Junho 2021**

# %%
mun_rj_junho_2021_desvio_obitos=  mun_rj_junho_2021['obitosNovos'].std()
mun_rj_junho_2021_desvio_obitos
# Out:
# 48.73107059545594

# %% [markdown]
#  * <font color="red"> **Móda dos Óbitos no Mês de Junho 2021**

# %%
mun_rj_junho_2021_moda_obitos=  mun_rj_junho_2021['obitosNovos'].mode()
mun_rj_junho_2021_moda_obitos
# Out:
# 0      0.0
# 1    106.0
# 2    124.0
# 3    137.0
# dtype: float64

# %% [markdown]
#  * <font color="red"> **Análise de óbitos do Município do RJ no Mês de Junho 2021**

# %%
quartis_mun_rj_junho_obitos = mun_rj_junho_2021['obitosNovos'].quantile([0.25,0.5,0.75])
quartis_mun_rj_junho_obitos
# Out:
# 0.25     29.25
# 0.50     93.00
# 0.75    111.50
# Name: obitosNovos, dtype: float64

# %%
boxplot_mun_rj_junho_obtitos = mun_rj_junho_2021.boxplot(column=['obitosNovos'], showfliers=False)
boxplot_mun_rj_junho_obtitos .plot()
plt.title("Distribuição de novos Óbitos no Município do RJ - Junho 2021")
plt.show()

# %% [markdown]
# ### Métricas do município do Rio de Janeiro  **em todo o período de 2020/2021**

# %% [markdown]
# * <font color="ffd11b">**Média de Casos no período de 2020/2021**

# %%
geral_munic_rj['obitosAcumulado']
# Out:
# 502606     8344
# 502607     8358
# 502608     8371
# 502609     8419
# 502610     8499
#           ...
# 45999     29175
# 46000     29185
# 46001     29192
# 46002     29241
# 46003     29295
# Name: obitosAcumulado, Length: 348, dtype: int64

# %%
media_munic_rj_casos = geral_munic_rj['casosNovos'].mean()
media_munic_rj_casos
# Out:
# 882.1235632183908

# %% [markdown]
# * <font color="ffd11b">**Desvio padrão de Casos no período de 2020/2021**

# %%
dp_munic_rj_casos = geral_munic_rj['casosNovos'].std()
dp_munic_rj_casos
# Out:
# 935.6228113972337

# %% [markdown]
# * <font color="ffd11b">**Moda de Casos no período de 2020/2021**

# %%
moda_munic_rj_casos = geral_munic_rj['casosNovos'].mode()
moda_munic_rj_casos
# Out:
# 0    212
# dtype: int64

# %% [markdown]
# * <font color="ffd11b">**Análise  Casos no período de 2020/2021**

# %%
quartis_geral_munc_rj_casos = geral_munic_rj['casosNovos'].quantile([0.25,0.5,0.75,1])
quartis_geral_munc_rj_casos
# Out:
# 0.25     232.0
# 0.50     649.5
# 0.75    1224.5
# 1.00    7592.0
# Name: casosNovos, dtype: float64

# %%
boxplot_mun_geral_munc_rj_casos = geral_munic_rj.boxplot(column=['casosNovos'], showfliers=False)
boxplot_mun_geral_munc_rj_casos.plot()
plt.title("Distribuição de novos Casos no Município do RJ - 2020-2021")
plt.show()

# %% [markdown]
# * <font color="red">**Média de Óbitos no período de 2020/2021**

# %%
media_munic_rj_obitos = geral_munic_rj['obitosNovos'].mean()
media_munic_rj_obitos
# Out:
# 60.30172413793103

# %% [markdown]
# * <font color="red">**Desvio padrão de Óbitos no período de 2020/2021**

# %%
dp_munic_rj_obitos = geral_munic_rj['obitosNovos'].std()
dp_munic_rj_obitos
# Out:
# 49.2851878118851

# %% [markdown]
# * <font color="red">**Moda de Óbitos no período de 2020/2021**

# %%
moda_munic_rj_obitos = geral_munic_rj['obitosNovos'].mode()
moda_munic_rj_obitos
# Out:
# 0    0.0
# dtype: float64

# %% [markdown]
# * <font color="red">** **Análise** gráfico de Óbitos no período de 2020/2021**

# %%
quartis_geral_munc_rj_obitos = geral_munic_rj['obitosNovos'].quantile([0.25,0.5,0.75,1])
quartis_geral_munc_rj_obitos
# Out:
# 0.25     15.75
# 0.50     53.00
# 0.75     96.00
# 1.00    246.00
# Name: obitosNovos, dtype: float64

# %%
boxplot_mun_geral_munc_rj_obitos = geral_munic_rj.boxplot(column=['obitosNovos'], showfliers=False)
boxplot_mun_geral_munc_rj_obitos.plot()
plt.title("Distribuição de novos Óbitos no Município do RJ - 2020-2021")
plt.show()

# %% [markdown]
# # Análise de dados do Estado do RJ

# %%
geral_estado_rj = data_geral[(data_geral['estado'] =='RJ') & (data_geral['codmun'].isna())]

geral_estado_rj.sort_values(by='data')
geral_estado_rj
# Out:
#        regiao estado municipio  coduf  codmun codRegiaoSaude nomeRegiaoSaude  \
# 2908  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2909  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2910  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2911  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2912  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# ...       ...    ...       ...    ...     ...            ...             ...
# 275   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 276   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 277   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 278   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 279   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
#
#             data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 2908  2020-08-01       31.0        17264943.0        167213.0        1718
# 2909  2020-08-02       32.0        17264943.0        167225.0          12
# 2910  2020-08-03       32.0        17264943.0        168064.0         839
# 2911  2020-08-04       32.0        17264943.0        168911.0         847
# 2912  2020-08-05       32.0        17264943.0        172679.0        3768
# ...          ...        ...               ...             ...         ...
# 275   2021-07-10       27.0        17264943.0        981088.0        3318
# 276   2021-07-11       28.0        17264943.0        981839.0         751
# 277   2021-07-12       28.0        17264943.0        982609.0         770
# 278   2021-07-13       28.0        17264943.0        984554.0        1945
# 279   2021-07-14       28.0        17264943.0        986233.0        1679
#
#       obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 2908            13556         79.0               NaN                    NaN
# 2909            13572         16.0               NaN                    NaN
# 2910            13604         32.0               NaN                    NaN
# 2911            13715        111.0               NaN                    NaN
# 2912            13855        140.0               NaN                    NaN
# ...               ...          ...               ...                    ...
# 275             56755        196.0               NaN                    NaN
# 276             56808         53.0               NaN                    NaN
# 277             56848         40.0               NaN                    NaN
# 278             56947         99.0               NaN                    NaN
# 279             57075        128.0               NaN                    NaN
#
#       interior/metropolitana
# 2908                     NaN
# 2909                     NaN
# 2910                     NaN
# 2911                     NaN
# 2912                     NaN
# ...                      ...
# 275                      NaN
# 276                      NaN
# 277                      NaN
# 278                      NaN
# 279                      NaN
#
# [348 rows x 17 columns]

# %%
geral_estado_rj['data'] = pd.to_datetime(geral_estado_rj['data'])

# %% [markdown]
# ### Métricas do Estado do Rio de Janeiro  **Junho 2021**

# %%
estado_rj_junho = geral_estado_rj[(geral_estado_rj['data'] >= '2021-06-01' ) & (geral_estado_rj['data'] <= '2021-06-30' )]

# %%
estado_rj_junho['obitosNovos'].sum()
# Out:
# 4886.0

# %% [markdown]
# * <font color="ffd11b">**Média de Casos no estado em junho 2021**

# %%
media_estado_rj_junho_casos = estado_rj_junho['casosNovos'].mean()
media_estado_rj_junho_casos
# Out:
# 3094.5333333333333

# %% [markdown]
# * <font color="ffd11b">**Desvio padrão de Casos no estado em junho 2021**

# %%
desvio_estado_rj_junho_obitos = estado_rj_junho['casosNovos'].std()
desvio_estado_rj_junho_obitos
# Out:
# 1755.471284266723

# %% [markdown]
# * <font color="ffd11b">**Moda de Casos no estado em junho 2021**

# %%
moda_rj_junho_casos = estado_rj_junho['casosNovos'].mode()
moda_rj_junho_casos
# Out:
# 0      344
# 1      386
# 2      483
# 3      592
# 4      775
# 5      883
# 6     1190
# 7     1520
# 8     1681
# 9     2113
# 10    2326
# 11    2498
# 12    3093
# 13    3431
# 14    3520
# 15    3530
# 16    3566
# 17    3939
# 18    3954
# 19    4072
# 20    4178
# 21    4187
# 22    4341
# 23    4372
# 24    4422
# 25    4701
# 26    5022
# 27    5258
# 28    6092
# 29    6367
# dtype: int64

# %% [markdown]
# * <font color="ffd11b">**Análise de  Casos no estado em junho 2021**

# %%
quartis_estado_rj_junho_casos = estado_rj_junho['casosNovos'].quantile([0.25,0.5,0.75])
quartis_estado_rj_junho_casos
# Out:
# 0.25    1560.25
# 0.50    3525.00
# 0.75    4302.50
# Name: casosNovos, dtype: float64

# %%
boxplot_mun_estado_rj_junho_casos = estado_rj_junho.boxplot(column=['casosNovos'], showfliers=False)
boxplot_mun_estado_rj_junho_casos .plot()
plt.title("Distribuição de novos Casos no Estado do RJ - Junho-2021")
plt.show()

# %% [markdown]
# * <font color="red">**Média de Óbitos no estado em junho 2021**

# %%
media_estado_rj_junho_obitos = estado_rj_junho['obitosNovos'].mean()
media_estado_rj_junho_obitos
# Out:
# 162.86666666666667

# %% [markdown]
# * <font color="red">**Desvio padrão de Casos no estado em junho 2021**

# %%
desvio_estado_rj_junho_obitos = estado_rj_junho['obitosNovos'].std()
desvio_estado_rj_junho_obitos
# Out:
# 96.19188199073527

# %% [markdown]
# * <font color="red">**Moda de Óbitos no estado em junho 2021**

# %%
moda_rj_junho_obitos = estado_rj_junho['obitosNovos'].mode()
moda_rj_junho_obitos
# Out:
# 0     17.0
# 1    256.0
# dtype: float64

# %% [markdown]
# * <font color="red">**Análise de Óbitos no estado em junho 2021**

# %%
quartis_estado_rj_junho_obitos = estado_rj_junho['obitosNovos'].quantile([0.25,0.5,0.75])
quartis_estado_rj_junho_obitos
# Out:
# 0.25     91.50
# 0.50    179.00
# 0.75    232.75
# Name: obitosNovos, dtype: float64

# %%
boxplot_mun_estado_rj_junho_obitos = estado_rj_junho.boxplot(column=['obitosNovos'], showfliers=False)
boxplot_mun_estado_rj_junho_obitos.plot()
plt.title("Distribuição de novos óbitos no Estado do RJ - Junho-2021")
plt.show()

# %% [markdown]
# ### Métricas do Estado RJ  **em todo o período de 2020/2021**

# %% [markdown]
# * <font color="ffd11b">**Média de Casos no estado  2020/2021**

# %%
media_estado_rj_casos =  geral_estado_rj['casosNovos'].mean()
media_estado_rj_casos
# Out:
# 2358.442528735632

# %% [markdown]
# * <font color="ffd11b">**Desvio padrão de Casos no estado  2020/2021**

# %%
desvios_estado_rj_casos =  geral_estado_rj['casosNovos'].std()
desvios_estado_rj_casos
# Out:
# 1693.7520325290184

# %% [markdown]
# * <font color="ffd11b">** padrão de Casos no estado  2020/2021**

# %%
moda_estado_rj_casos =  geral_estado_rj['casosNovos'].mode()
moda_estado_rj_casos
# Out:
# 0       0
# 1     234
# 2     268
# 3     751
# 4    1081
# 5    1180
# 6    2158
# 7    4039
# 8    4160
# 9    5118
# dtype: int64

# %% [markdown]
# * <font color="ffd11b">**Análise de Casos no estado  2020/2021**

# %%
quartis_estado_rj_casos = geral_estado_rj['casosNovos'].quantile([0.25,0.5,0.75])
quartis_estado_rj_casos
# Out:
# 0.25     874.75
# 0.50    2113.50
# 0.75    3561.50
# Name: casosNovos, dtype: float64

# %%
geral_estado_rj
# Out:
#        regiao estado municipio  coduf  codmun codRegiaoSaude nomeRegiaoSaude  \
# 2908  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2909  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2910  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2911  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2912  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# ...       ...    ...       ...    ...     ...            ...             ...
# 275   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 276   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 277   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 278   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 279   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 2908 2020-08-01       31.0        17264943.0        167213.0        1718
# 2909 2020-08-02       32.0        17264943.0        167225.0          12
# 2910 2020-08-03       32.0        17264943.0        168064.0         839
# 2911 2020-08-04       32.0        17264943.0        168911.0         847
# 2912 2020-08-05       32.0        17264943.0        172679.0        3768
# ...         ...        ...               ...             ...         ...
# 275  2021-07-10       27.0        17264943.0        981088.0        3318
# 276  2021-07-11       28.0        17264943.0        981839.0         751
# 277  2021-07-12       28.0        17264943.0        982609.0         770
# 278  2021-07-13       28.0        17264943.0        984554.0        1945
# 279  2021-07-14       28.0        17264943.0        986233.0        1679
#
#       obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 2908            13556         79.0               NaN                    NaN
# 2909            13572         16.0               NaN                    NaN
# 2910            13604         32.0               NaN                    NaN
# 2911            13715        111.0               NaN                    NaN
# 2912            13855        140.0               NaN                    NaN
# ...               ...          ...               ...                    ...
# 275             56755        196.0               NaN                    NaN
# 276             56808         53.0               NaN                    NaN
# 277             56848         40.0               NaN                    NaN
# 278             56947         99.0               NaN                    NaN
# 279             57075        128.0               NaN                    NaN
#
#       interior/metropolitana
# 2908                     NaN
# 2909                     NaN
# 2910                     NaN
# 2911                     NaN
# 2912                     NaN
# ...                      ...
# 275                      NaN
# 276                      NaN
# 277                      NaN
# 278                      NaN
# 279                      NaN
#
# [348 rows x 17 columns]

# %%
boxplot_estado_rj_casos = geral_estado_rj.boxplot(column=['casosNovos'], showfliers=False)
boxplot_estado_rj_casos.plot()
plt.title("Distribuição de novos Casos no Estado do RJ - 2020-2021")
plt.show()

# %% [markdown]
# * <font color="red">**Média de óbitos no estado  2020/2021**

# %%
media_estado_rj_obitos =  geral_estado_rj['obitosNovos'].mean()
media_estado_rj_obitos
# Out:
# 125.2816091954023

# %% [markdown]
# * <font color="red">**Desfio padrão de óbitos no estado  2020/2021**

# %%
desvios_estado_rj_obitos =  geral_estado_rj['obitosNovos'].std()
desvios_estado_rj_obitos
# Out:
# 98.25691786659208

# %% [markdown]
# * <font color="red">**Moda de óbitos no estado  2020/2021**

# %%
moda_estado_rj_obitos =  geral_estado_rj['obitosNovos'].mode()
moda_estado_rj_obitos
# Out:
# 0    24.0
# dtype: float64

# %% [markdown]
# * <font color="red">**Análise óbitos no estado  2020/2021**

# %%
quartis_estado_rj_obitos = geral_estado_rj['obitosNovos'].quantile([0.25,0.5,0.75])
quartis_estado_rj_obitos
# Out:
# 0.25     42.75
# 0.50    106.50
# 0.75    185.25
# Name: obitosNovos, dtype: float64

# %%
boxplot_estado_rj_obitos = geral_estado_rj.boxplot(column=['obitosNovos'], showfliers=False)
boxplot_estado_rj_obitos.plot()
plt.title("Distribuição de Òbitos Casos no Estado do RJ - 2020-2021")
plt.show()

# %% [markdown]
# # Análise comparativa: Município RJ vs Estado RJ

# %% [markdown]
# ### <font color="ffd11b">***Comparativo da média de casos do Município RJ X Estado RJ***

# %%
metricas_munc_rj_casos = [mun_rj_junho_2021_media_casos, media_munic_rj_casos]
metricas_estado_rj_casos = [media_estado_rj_junho_casos, media_estado_rj_casos]

# %%
casos = pd.DataFrame({"MunRJ":metricas_munc_rj_casos ,"EsRJ": metricas_estado_rj_casos}, index = ['junho_2021', 'total_20/21'])
casos
# Out:
#                    MunRJ         EsRJ
# junho_2021   1434.466667  3094.533333
# total_20/21   882.123563  2358.442529

# %%
casos.plot.bar(color=["Green","blue"])
plt.title('Comparativo: Média de casos - Município RJ vs Estado RJ')
plt.show()

# %%
geral_estado_rj
# Out:
#        regiao estado municipio  coduf  codmun codRegiaoSaude nomeRegiaoSaude  \
# 2908  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2909  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2910  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2911  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2912  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# ...       ...    ...       ...    ...     ...            ...             ...
# 275   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 276   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 277   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 278   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 279   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 2908 2020-08-01       31.0        17264943.0        167213.0        1718
# 2909 2020-08-02       32.0        17264943.0        167225.0          12
# 2910 2020-08-03       32.0        17264943.0        168064.0         839
# 2911 2020-08-04       32.0        17264943.0        168911.0         847
# 2912 2020-08-05       32.0        17264943.0        172679.0        3768
# ...         ...        ...               ...             ...         ...
# 275  2021-07-10       27.0        17264943.0        981088.0        3318
# 276  2021-07-11       28.0        17264943.0        981839.0         751
# 277  2021-07-12       28.0        17264943.0        982609.0         770
# 278  2021-07-13       28.0        17264943.0        984554.0        1945
# 279  2021-07-14       28.0        17264943.0        986233.0        1679
#
#       obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 2908            13556         79.0               NaN                    NaN
# 2909            13572         16.0               NaN                    NaN
# 2910            13604         32.0               NaN                    NaN
# 2911            13715        111.0               NaN                    NaN
# 2912            13855        140.0               NaN                    NaN
# ...               ...          ...               ...                    ...
# 275             56755        196.0               NaN                    NaN
# 276             56808         53.0               NaN                    NaN
# 277             56848         40.0               NaN                    NaN
# 278             56947         99.0               NaN                    NaN
# 279             57075        128.0               NaN                    NaN
#
#       interior/metropolitana
# 2908                     NaN
# 2909                     NaN
# 2910                     NaN
# 2911                     NaN
# 2912                     NaN
# ...                      ...
# 275                      NaN
# 276                      NaN
# 277                      NaN
# 278                      NaN
# 279                      NaN
#
# [348 rows x 17 columns]

# %%
casos2 = pd.DataFrame({"MunRJ":geral_munic_rj['casosNovos']  ,"EsRJ": geral_estado_rj['casosNovos'] })
geral_estado_rj
# Out:
#        regiao estado municipio  coduf  codmun codRegiaoSaude nomeRegiaoSaude  \
# 2908  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2909  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2910  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2911  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 2912  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# ...       ...    ...       ...    ...     ...            ...             ...
# 275   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 276   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 277   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 278   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
# 279   Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 2908 2020-08-01       31.0        17264943.0        167213.0        1718
# 2909 2020-08-02       32.0        17264943.0        167225.0          12
# 2910 2020-08-03       32.0        17264943.0        168064.0         839
# 2911 2020-08-04       32.0        17264943.0        168911.0         847
# 2912 2020-08-05       32.0        17264943.0        172679.0        3768
# ...         ...        ...               ...             ...         ...
# 275  2021-07-10       27.0        17264943.0        981088.0        3318
# 276  2021-07-11       28.0        17264943.0        981839.0         751
# 277  2021-07-12       28.0        17264943.0        982609.0         770
# 278  2021-07-13       28.0        17264943.0        984554.0        1945
# 279  2021-07-14       28.0        17264943.0        986233.0        1679
#
#       obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 2908            13556         79.0               NaN                    NaN
# 2909            13572         16.0               NaN                    NaN
# 2910            13604         32.0               NaN                    NaN
# 2911            13715        111.0               NaN                    NaN
# 2912            13855        140.0               NaN                    NaN
# ...               ...          ...               ...                    ...
# 275             56755        196.0               NaN                    NaN
# 276             56808         53.0               NaN                    NaN
# 277             56848         40.0               NaN                    NaN
# 278             56947         99.0               NaN                    NaN
# 279             57075        128.0               NaN                    NaN
#
#       interior/metropolitana
# 2908                     NaN
# 2909                     NaN
# 2910                     NaN
# 2911                     NaN
# 2912                     NaN
# ...                      ...
# 275                      NaN
# 276                      NaN
# 277                      NaN
# 278                      NaN
# 279                      NaN
#
# [348 rows x 17 columns]

# %% [markdown]
# ### <font color="red">***Comparativo da média de Óbitos do Munícipio RJ X Estado RJ***

# %%
metricas_munc_rj_obitos = [mun_rj_junho_2021_media_obitos, media_munic_rj_obitos]
metricas_estado_rj_obitos = [media_estado_rj_junho_obitos, media_estado_rj_obitos]
obitos = pd.DataFrame({"MunRJ":metricas_munc_rj_obitos ,"EsRJ": metricas_estado_rj_obitos}, index = ['junho_2021', 'total_20/21'])
obitos
# Out:
#                  MunRJ        EsRJ
# junho_2021   77.200000  162.866667
# total_20/21  60.301724  125.281609

# %%
obitos.plot.bar(color=["yellow","red"])
plt.title('Comparativo: Média de Óbitos - Município RJ vs Estado RJ')
plt.show()

# %% [markdown]
# # Outras Métricas do Estado

# %% [markdown]
# ### Total de Casos e Óbitos no Estado do Rio de Janeiro

# %%
acumulado_rj = geral_estado_rj.loc[geral_estado_rj['data'] == '2021-07-14']
acumulado_rj
# Out:
#       regiao estado municipio  coduf  codmun codRegiaoSaude nomeRegiaoSaude  \
# 279  Sudeste     RJ       NaN   33.0     NaN            NaN             NaN
#
#           data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 279 2021-07-14       28.0        17264943.0        986233.0        1679
#
#      obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 279            57075        128.0               NaN                    NaN
#
#      interior/metropolitana
# 279                     NaN

# %%
tudo_rj = data_geral[(data_geral.estado =='RJ')  & (data_geral['data'] == '2021-07-14')]

# %% [markdown]
# ### Métricas das Macros Regiões do Estado do Rio de Janeiro em toda pandemia 2020/2021

# %%
regioes_rj = tudo_rj.groupby(['nomeRegiaoSaude']).sum()
regioes_rj
# Out:
#                      coduf     codmun  semanaEpi  populacaoTCU2019  \
# nomeRegiaoSaude
# BAIA DA ILHA GRANDE   99.0   990650.0       84.0          291418.0
# BAIXADA LITORANEA    297.0  2971977.0      252.0          839958.0
# CENTRO-SUL           363.0  3633742.0      308.0          340526.0
# MEDIO PARAIBA        396.0  3964463.0      336.0          913698.0
# METROPOLITANA I      396.0  3963781.0      336.0        10497016.0
# METROPOLITANA II     231.0  2312845.0      196.0         2116506.0
# NOROESTE             462.0  4623763.0      392.0          348191.0
# NORTE                264.0  2642443.0      224.0          945425.0
# SERRANA              528.0  5285075.0      448.0          972205.0
#
#                      casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# nomeRegiaoSaude
# BAIA DA ILHA GRANDE         19706.0           4              706          4.0
# BAIXADA LITORANEA           54229.0           2             2489          2.0
# CENTRO-SUL                  33232.0           2             1137          2.0
# MEDIO PARAIBA               87572.0          10             3046         10.0
# METROPOLITANA I            485020.0        1573            36606         89.0
# METROPOLITANA II           124797.0          79             6286         12.0
# NOROESTE                    31016.0           1              827          1.0
# NORTE                       67480.0           1             2630          1.0
# SERRANA                     83181.0           7             3348          7.0
#
#                      Recuperadosnovos  emAcompanhamentoNovos  \
# nomeRegiaoSaude
# BAIA DA ILHA GRANDE               0.0                    0.0
# BAIXADA LITORANEA                 0.0                    0.0
# CENTRO-SUL                        0.0                    0.0
# MEDIO PARAIBA                     0.0                    0.0
# METROPOLITANA I                   0.0                    0.0
# METROPOLITANA II                  0.0                    0.0
# NOROESTE                          0.0                    0.0
# NORTE                             0.0                    0.0
# SERRANA                           0.0                    0.0
#
#                      interior/metropolitana
# nomeRegiaoSaude
# BAIA DA ILHA GRANDE                     0.0
# BAIXADA LITORANEA                       0.0
# CENTRO-SUL                              1.0
# MEDIO PARAIBA                           0.0
# METROPOLITANA I                        12.0
# METROPOLITANA II                        6.0
# NOROESTE                                0.0
# NORTE                                   0.0
# SERRANA                                 3.0

# %%
regioes_rj.plot.bar(y=['casosAcumulado', 'obitosAcumulado'], color=['yellow','red'])
plt.xlabel('Regiões')
plt.ylabel('Qtde de casos')
plt.title('Casos por Região do Estado do RJ')
plt.show()

# %% [markdown]
# ### Métricas dos 10 municípios com mais Casos e Óbitos

# %%
total_caos_estado_10munc = tudo_rj
total_caos_estado_10munc = total_caos_estado_10munc[total_caos_estado_10munc['municipio'].notna()]
total_caos_estado_10munc.set_index('municipio', inplace=True)

# %%
casos  = total_caos_estado_10munc.sort_values(by='casosAcumulado', ascending=False).head(10)
casos.casosAcumulado
# Out:
# municipio
# Rio de Janeiro           378301.0
# São Gonçalo               51896.0
# Niterói                   40966.0
# Volta Redonda             33636.0
# Campos dos Goytacazes     27797.0
# Macaé                     26610.0
# Teresópolis               24747.0
# Duque de Caxias           22344.0
# Nova Friburgo             20987.0
# Belford Roxo              20716.0
# Name: casosAcumulado, dtype: float64

# %%
casos.sort_values(by=['casosAcumulado'],inplace=True)
casos.plot.bar(y='casosAcumulado')
plt.xlabel('Municípios')
plt.ylabel('Qtde de casos')
plt.title('Os 10 Municípios com mais Casos no Estado ')
plt.show()

# %% [markdown]
# ### Os 10 Municípios com mais Óbitos

# %%
obitos_por_munic_top_10  = total_caos_estado_10munc.sort_values(by='obitosAcumulado', ascending=False).head(10)
obitos_por_munic_top_10.obitosAcumulado
# Out:
# municipio
# Rio de Janeiro           29295
# São Gonçalo               2764
# Niterói                   1897
# Nova Iguaçu               1742
# Campos dos Goytacazes     1573
# Duque de Caxias           1500
# Petrópolis                1295
# São João de Meriti        1088
# Volta Redonda             1066
# Teresópolis                790
# Name: obitosAcumulado, dtype: int64

# %%
obitos_por_munic_top_10.sort_values(by=['obitosAcumulado'],inplace=True)
obitos_por_munic_top_10.plot.bar(y='obitosAcumulado',color=['red'])
plt.xlabel('Municípios')
plt.ylabel('Qtde de casos')
plt.title('Os 10 Municípios com mais Óbitos no Estado ')
plt.show()

# %% [markdown]
# ### Média Móvel

# %%
serie_munc_geral = geral_munic_rj
serie_munc_geral.set_index('data', inplace=True)

# %%
serie_munc_geral
# Out:
#              regiao estado       municipio  coduf    codmun codRegiaoSaude  \
# data
# 2020-08-01  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 2020-08-02  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 2020-08-03  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 2020-08-04  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 2020-08-05  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# ...             ...    ...             ...    ...       ...            ...
# 2021-07-10  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 2021-07-11  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 2021-07-12  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 2021-07-13  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
# 2021-07-14  Sudeste     RJ  Rio de Janeiro   33.0  330455.0        33005.0
#
#             nomeRegiaoSaude  semanaEpi  populacaoTCU2019  casosAcumulado  \
# data
# 2020-08-01  METROPOLITANA I       31.0         6718903.0         71792.0
# 2020-08-02  METROPOLITANA I       32.0         6718903.0         71802.0
# 2020-08-03  METROPOLITANA I       32.0         6718903.0         72079.0
# 2020-08-04  METROPOLITANA I       32.0         6718903.0         72722.0
# 2020-08-05  METROPOLITANA I       32.0         6718903.0         73396.0
# ...                     ...        ...               ...             ...
# 2021-07-10  METROPOLITANA I       27.0         6718903.0        375242.0
# 2021-07-11  METROPOLITANA I       28.0         6718903.0        375616.0
# 2021-07-12  METROPOLITANA I       28.0         6718903.0        375908.0
# 2021-07-13  METROPOLITANA I       28.0         6718903.0        376763.0
# 2021-07-14  METROPOLITANA I       28.0         6718903.0        378301.0
#
#             casosNovos  obitosAcumulado  obitosNovos  Recuperadosnovos  \
# data
# 2020-08-01         470             8344         34.0               NaN
# 2020-08-02          10             8358         14.0               NaN
# 2020-08-03         277             8371         13.0               NaN
# 2020-08-04         643             8419         48.0               NaN
# 2020-08-05         674             8499         80.0               NaN
# ...                ...              ...          ...               ...
# 2021-07-10        1466            29175        133.0               NaN
# 2021-07-11         374            29185         10.0               NaN
# 2021-07-12         292            29192          7.0               NaN
# 2021-07-13         855            29241         49.0               NaN
# 2021-07-14        1538            29295         54.0               NaN
#
#             emAcompanhamentoNovos  interior/metropolitana
# data
# 2020-08-01                    NaN                     1.0
# 2020-08-02                    NaN                     1.0
# 2020-08-03                    NaN                     1.0
# 2020-08-04                    NaN                     1.0
# 2020-08-05                    NaN                     1.0
# ...                           ...                     ...
# 2021-07-10                    NaN                     1.0
# 2021-07-11                    NaN                     1.0
# 2021-07-12                    NaN                     1.0
# 2021-07-13                    NaN                     1.0
# 2021-07-14                    NaN                     1.0
#
# [348 rows x 16 columns]

# %%
media_movel_casos_muncrj = serie_munc_geral['casosNovos'].rolling(14).mean()
media_movel_casos_muncrj.plot()
plt.gcf().set_size_inches(10,5)
plt.tight_layout()
plt.title('Média Móvel(14 dias) de Casos do Muncícpio do RJ')
plt.show()

# %%
media_movel_obitos_muncrj = serie_munc_geral['obitosNovos'].rolling(14).mean()
media_movel_obitos_muncrj.plot(color=['red'])
plt.gcf().set_size_inches(12,5)
plt.title('Média Móvel(14 dias) de Óbitos do Muncícpio do RJ')
plt.show()
